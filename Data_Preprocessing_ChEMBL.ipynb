# %% [markdown]
# Part_01 for QSAR DATA processing

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 6.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client
# Out:
# /usr/local/lib/python3.13/dist-packages/chembl_webresource_client/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __version__ = __import__('pkg_resources').get_distribution('chembl_webresource_client').version

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target

target_query = target.search('Bioactivity_01.csv')

targets = pd.DataFrame.from_dict(target_query)

targets
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### **Select and retrieve bioactivity data for *H92c* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *H92c*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL614576'

# %%
selected_target = 'CHEMBL614576' # Temporarily defining selected_target to resolve NameError
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#      action_type activity_comment  activity_id  \
# 0           None             None      1782905
# 1           None             None      1782906
# 2           None             None      1782963
# 3           None             None      1782964
# 4           None             None      1782965
# ...          ...              ...          ...
# 1859        None             None     29287439
# 1860        None             None     29287440
# 1861        None             None     29287441
# 1862        None             None     29287442
# 1863        None             None     29287443
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL855628
# 1                                                    []    CHEMBL855629
# 2                                                    []    CHEMBL855628
# 3                                                    []    CHEMBL855628
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('H92C_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /tmp/ipykernel_1832/3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#      action_type activity_comment  activity_id  \
# 0           None             None      1782905
# 1           None             None      1782906
# 2           None             None      1782963
# 3           None             None      1782964
# 4           None             None      1782965
# ...          ...              ...          ...
# 1855        None             None     29273881
# 1856        None             None     29273882
# 1860        None             None     29287440
# 1862        None             None     29287442
# 1863        None             None     29287443
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL855628
# 1                                                    []    CHEMBL855629
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1828

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      action_type activity_comment  activity_id  \
# 0           None             None      1782905
# 2           None             None      1782963
# 3           None             None      1782964
# 4           None             None      1782965
# 5           None             None      1782966
# ...          ...              ...          ...
# 1855        None             None     29273881
# 1856        None             None     29273882
# 1860        None             None     29287440
# 1862        None             None     29287442
# 1863        None             None     29287443
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL855628
# 2                                                    []    CHEMBL855628
# 3                                                    []    CHEMBL855628
# 4                                                    []    CHEMBL855629
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL53463  COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...
# 2          CHEMBL217089  COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...
# 3          CHEMBL383964  CCOC(=O)N1CO[C@@H]2[C@H](C)O[C@@H](O[C@H]3C[C@...
# 4          CHEMBL384221  CCCCCOC(=O)N1CO[C@@H]2[C@H](C)O[C@@H](O[C@H]3C...
# 5          CHEMBL214810  CCCCOC(=O)N1CO[C@@H]2[C@H](C)O[C@@H](O[C@H]3C[...
# ...                 ...                                                ...
# 1855      CHEMBL6176884  CCOC(=O)COc1cc(OC)cc2c1[n+]([O-])c1ccccc1[n+]2...
# 1856      CHEMBL6176112  COc1cc(OC(C)=O)c2c(c1)[n+]([O-])c1ccccc1[n+]2[O-]
# 1860      CHEMBL6177465  C=CS(=O)(=O)N1CCC[C@@H](Nc2nc(N)nc(Nc3cccc(Oc4...
# 1862      CHEMBL6176872  C=CS(=O)(=O)N1CCC[C@@H](Nc2nc(N)nc(Nc3cccc(OCc...
# 1863      CHEMBL1873475  C=CC(=O)N1CCC[C@@H](n2nc(-c3ccc(Oc4ccccc4)cc3)...
#
#      standard_value
# 0             31.62
# 2             31.62
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('H92C_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('H92C_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL53463  COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...
# 1          CHEMBL217089  COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...
# 2          CHEMBL383964  CCOC(=O)N1CO[C@@H]2[C@H](C)O[C@@H](O[C@H]3C[C@...
# 3          CHEMBL384221  CCCCCOC(=O)N1CO[C@@H]2[C@H](C)O[C@@H](O[C@H]3C...
# 4          CHEMBL214810  CCCCOC(=O)N1CO[C@@H]2[C@H](C)O[C@@H](O[C@H]3C[...
# ...                 ...                                                ...
# 1823      CHEMBL6176884  CCOC(=O)COc1cc(OC)cc2c1[n+]([O-])c1ccccc1[n+]2...
# 1824      CHEMBL6176112  COc1cc(OC(C)=O)c2c(c1)[n+]([O-])c1ccccc1[n+]2[O-]
# 1825      CHEMBL6177465  C=CS(=O)(=O)N1CCC[C@@H](Nc2nc(N)nc(Nc3cccc(Oc4...
# 1826      CHEMBL6176872  C=CS(=O)(=O)N1CCC[C@@H](Nc2nc(N)nc(Nc3cccc(OCc...
# 1827      CHEMBL1873475  C=CC(=O)N1CCC[C@@H](n2nc(-c3ccc(Oc4ccccc4)cc3)...
#
#       standard_value         class
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('H92C_03_bioactivity_data_curated.csv', index=False)

# %% [markdown]
# ---
